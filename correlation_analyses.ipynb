# %% [markdown]
# <a href="https://colab.research.google.com/github/lfcseenu/covid_stats/blob/main/correlation_analyses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
link='https://raw.githubusercontent.com/lfcseenu/covid_stats/main/covid%20health%20score%20%202.csv'

# %%
covid_stats=pd.read_csv(link)

# %%
covid_stats
# Out:
#     order of covid shutdown  Median Household Income    2020  Population   \
# 0                      48.0                          45155.0    5024279.0
# 1                      10.0                          68019.0     733391.0
# 2                      36.0                          52065.0    7151502.0
# 3                      49.0                          43407.0    3011524.0
# 4                       7.0                          76132.0   39538223.0
# 5                      14.0                          66142.0    5773714.0
# 6                       5.0                          76779.0    3605944.0
# 7                       6.0                          76406.0     989948.0
# 8                       1.0                          88311.0     689545.0
# 9                      38.0                          51277.0   21538187.0
# 10                     25.0                          58050.0   10711908.0
# 11                     29.0                          57087.0    1455271.0
# ...

# %%
covid_stats.corr().round(2)
# Out:
#                                  order of covid shutdown  \
# order of covid shutdown                             1.00
# Median Household Income    2020                    -0.97
# Population                                         -0.21
# Number of households                               -0.21
# Health score                                       -0.69
#
#                                  Median Household Income    2020  Population   \
# order of covid shutdown                                    -0.97        -0.21
# Median Household Income    2020                             1.00         0.23
# Population                                                  0.23         1.00
# Number of households                                        0.23         1.00
# Health score                                                0.70         0.09
#
#                                  Number of households  Health score
# order of covid shutdown                         -0.21         -0.69
# ...

# %%
sns.scatterplot(x ='', y ='C', data = prius_df)
# Out:
# <Axes: xlabel='Car_Age', ylabel='CAR_PRICE'>

# %%
sns.regplot(x ='Median Household Income 2020', y ='order of covid shutdown', data = covid_stats)
# Out:
# <Axes: xlabel='Median Household Income 2020', ylabel='order of covid shutdown'>

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
Y = covid_stats['order of covid shutdown']
X = covid_stats['Median Household Income 2020']
X = sm.add_constant(X)

reg_Equation = sm.OLS(Y,X ).fit()
print(reg_Equation.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     order of covid shutdown   R-squared:                       0.937
# Model:                                 OLS   Adj. R-squared:                  0.936
# Method:                      Least Squares   F-statistic:                     731.3
# Date:                     Fri, 29 Sep 2023   Prob (F-statistic):           4.14e-31
# Time:                             17:42:03   Log-Likelihood:                -138.93
# No. Observations:                       51   AIC:                             281.9
# Df Residuals:                           49   BIC:                             285.7
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...
